# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
from sklearn import metrics
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder    # for label enconding convertion of object to string
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import mean_squared_error, r2_score

# %%
data=pd.read_csv("cricket1.csv")
data
# Out:
#       Match ID  Overs Played  Wickets Lost  Run Rate Home/Away  \
# 0            1             7             1     11.04      Away
# 1            2            20            10     11.87      Home
# 2            3            15             7      6.14      Home
# 3            4            11             8      8.84      Home
# 4            5             8             0      9.56      Home
# ...        ...           ...           ...       ...       ...
# 1495      1496            15             8      9.82      Home
# 1496      1497             2            10     13.41      Home
# 1497      1498             3             6      7.21      Home
# 1498      1499            17             6      8.81      Away
# 1499      1500            12             0     13.08      Away
#
#       Opponent Strength Pitch Condition   Weather  Predicted_Score
# 0                     3         Bowling     Sunny               82
# 1                     5         Bowling     Sunny              204
# ...

# %%
encoder=LabelEncoder()
for column in['Pitch Condition','Weather','Home/Away']:
    data[column]=encoder.fit_transform(data[column])
print(data.head())
# Out:
#    Match ID  Overs Played  Wickets Lost  Run Rate  Home/Away  \
# 0         1             7             1     11.04          0
# 1         2            20            10     11.87          1
# 2         3            15             7      6.14          1
# 3         4            11             8      8.84          1
# 4         5             8             0      9.56          1
#
#    Opponent Strength  Pitch Condition  Weather  Predicted_Score
# 0                  3                2        2               82
# 1                  5                2        2              204
# 2                  7                0        2              105
# 3                  9                1        0              121
# 4                  2                0        2              104

# %%
data["Predicted_Score"].value_counts()
# Out:
# Predicted_Score
# 33     16
# 90     16
# 25     15
# 35     15
# 76     14
#        ..
# 314     1
# 273     1
# 338     1
# 223     1
# 303     1
# Name: count, Length: 298, dtype: int64

# %%
x=data.drop(columns=['Predicted_Score','Match ID'])

# %%
y=data["Predicted_Score"]

# %%
scaler=StandardScaler()
x_scaled=scaler.fit_transform(x)

# %%
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=0.2,random_state=42)

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1200, 7)
# (300, 7)
# (1200,)
# (300,)

# %%
k=2
knn=KNeighborsRegressor(n_neighbors=k)
knn.fit(x_train,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=2)

# %%
y_pred=knn.predict(x_test)
y_pred
# Out:
# array([177.5,  72. ,  23. , 302. ,  55. ,  89. ,  62. ,  27. , 118.5,
#        210.5,  60.5,  67.5,  67.5, 235.5, 160. ,  22.5,  48. ,  77.5,
#        258.5,  46.5,  80. ,  42.5, 107. , 229. ,  28. ,  95. , 197. ,
#         58.5, 169.5, 161. , 243. , 170.5,  89.5, 237. , 207.5, 169. ,
#         26.5,  95.5, 125.5,  84.5, 164. , 193.5,  91.5,  52.5,  58.5,
#         66. , 132. , 174. ,  39. ,  60.5,  42. ,  77.5, 141.5, 232.5,
#        169. ,  88.5, 290.5, 108.5, 101.5,  21. , 181.5, 309.5,  91. ,
#        205. ,  68.5,  95.5,  85.5,  34. ,  27.5,  57. ,  44.5, 173. ,
#        101. ,  71. , 145.5,  75. ,  78.5,  34.5, 142.5, 110. ,  23. ,
#        212. ,  43.5, 103. ,  33. , 116.5, 198.5, 141.5,  65. ,  66.5,
#         52. , 202. ,  86. ,  59.5, 131. , 163.5, 152.5,  43. ,  23. ,
#         20.5,  15. ,  95. , 135. , 149.5,  58. , 106. ,  71. ,  76. ,
#        152. ,  80.5, 182. ,  30.5, 136.5, 131. ,  63.5,  60. , 197.5,
# ...

# %%
mse=mean_squared_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)
print("Mean square error",mse)
print("R-squared:",r2)
# Out:
# Mean square error 755.08
# R-squared: 0.8517944627706844
